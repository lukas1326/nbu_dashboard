# %%
import requests
import pandas as pd
import json

# %%
url= 'https://bank.gov.ua/NBUStatService/v1/statdirectory/banksfinrep?date=20180101&period=m&json'

# %%
r=requests.get(url)

# %%
source=r.json()
source
# Out:
# [{'dt': '20180101',
#   'txt': 'Активи - Резерви під знецінення кредитів та заборгованості клієнтів-фізичних осіб',
#   'txten': 'Assets - Provision for impairment of loans and receivables from individuals',
#   'id_api': 'BS1_AssetsProvLoansIndiv',
#   'leveli': 4,
#   'parent': 'BS1_AssetsLoansIndiv',
#   'freq': 'M',
#   'nkb': ' 49',
#   'mfo': '353100',
#   'fullname': 'Полікомбанк',
#   'gr_bank': 'E',
#   'r034': '2',
#   'value': -0.0895,
#   'tzep': 'T070_7'},
#  {'dt': '20180101',
#   'txt': 'Активи - Резерви під знецінення кредитів та заборгованості клієнтів-фізичних осіб',
#   'txten': 'Assets - Provision for impairment of loans and receivables from individuals',
#   'id_api': 'BS1_AssetsProvLoansIndiv',
#   'leveli': 4,
#   'parent': 'BS1_AssetsLoansIndiv',
#   'freq': 'M',
#   'nkb': '290',
#   'mfo': '300506',
#   'fullname': 'АТ "ПЕРШИЙ ІНВЕСТИЦІЙНИЙ БАНК"',
#   'gr_bank': 'E',
#   'r034': '1',
#   'value': -0.5868,
#   'tzep': 'T070_7'},
#  {'dt': '20180101',
# ...

# %%
data=pd.DataFrame(source)

# %%
data=pd.DataFrame(source)
data.dt.unique()
# Out:
# array(['20180101', '20180201', '20180301', '20180401', '20180501',
#        '20180601', '20180701', '20180801', '20180901', '20181001',
#        '20181101', '20181201', '20190101', '20190201', '20190301',
#        '20190501', '20190401', '20190601', '20190701', '20190801',
#        '20190901', '20191001', '20191101', '20191201', '20200101',
#        '20200201', '20200301', '20200401', '20200501', '20200601',
#        '20200701', '20200801'], dtype=object)

# %%
len(data.leveli.unique())
# Out:
# 4
